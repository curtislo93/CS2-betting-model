# %%
import pandas as pd
import numpy as np
from google.colab import drive
import re
import warnings
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns

warnings.filterwarnings("ignore")

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Functions

# %%
def calculate_round_winner(cs2, max_round):
    for round_number in range(1, max_round + 1):
        conditions = []
        choices = ['Favorite', 'Underdog', 'Favorite', 'Underdog']

        # Define conditions based on round number
        if round_number == 1:
            conditions = [
                (cs2['Moneyline A'] < cs2['Moneyline B']) & (cs2['R1 Score (A)'] > cs2['R1 Score (B)']),
                (cs2['Moneyline A'] > cs2['Moneyline B']) & (cs2['R1 Score (A)'] > cs2['R1 Score (B)']),
                (cs2['Moneyline B'] < cs2['Moneyline A']) & (cs2['R1 Score (B)'] > cs2['R1 Score (A)']),
                (cs2['Moneyline B'] > cs2['Moneyline A']) & (cs2['R1 Score (B)'] > cs2['R1 Score (A)'])
            ]
        elif round_number == 2:
            conditions = [
                (cs2['Moneyline A'] < cs2['Moneyline B']) & (cs2['R2 Score (A)'] > cs2['R2 Score (B)']),
                (cs2['Moneyline A'] > cs2['Moneyline B']) & (cs2['R2 Score (A)'] > cs2['R2 Score (B)']),
                (cs2['Moneyline B'] < cs2['Moneyline A']) & (cs2['R2 Score (B)'] > cs2['R2 Score (A)']),
                (cs2['Moneyline B'] > cs2['Moneyline A']) & (cs2['R2 Score (B)'] > cs2['R2 Score (A)'])
            ]
        elif round_number == 3:
            # Check if the 'R3 Score' columns exist
            if 'R3 Score (A)' in cs2.columns and 'R3 Score (B)' in cs2.columns:
                conditions = [
                    (cs2['Moneyline A'] < cs2['Moneyline B']) & (cs2['R3 Score (A)'] > cs2['R3 Score (B)']),
                    (cs2['Moneyline A'] > cs2['Moneyline B']) & (cs2['R3 Score (A)'] > cs2['R3 Score (B)']),
                    (cs2['Moneyline B'] < cs2['Moneyline A']) & (cs2['R3 Score (B)'] > cs2['R3 Score (A)']),
                    (cs2['Moneyline B'] > cs2['Moneyline A']) & (cs2['R3 Score (B)'] > cs2['R3 Score (A)'])
                ]

        # Apply conditions and choices
        if conditions:
            cs2[f'Round {round_number} Winner'] = np.select(conditions, choices, default='')
        else:
            cs2[f'Round {round_number} Winner'] = ''

    return cs2

# %% [markdown]
# # CS Data

# %%
fp = '/content/drive/My Drive/Sports Betting/CS2 - Data.xlsx'

cs2 = pd.read_excel(fp)

# %%
cs2
# Out:
#           Date       Type                                             League  \
# 0   2024-04-15     Online  ESL Challenger Jonkoping 2024 Europe Closed Qu...
# 1   2024-04-15     Online  ESL Challenger Jonkoping 2024 Europe Closed Qu...
# 2   2024-04-15     Online  ESL Challenger Jonkoping 2024 Europe Closed Qu...
# 3   2024-04-15     Online  ESL Challenger Jonkoping 2024 Europe Closed Qu...
# 4   2024-03-31      Major                      PGL CS2 Major Copenhagen 2024
# ..         ...        ...                                                ...
# 262 2024-04-12  Intl. LAN                                   IEM Chengdu 2024
# 263 2024-04-12  Intl. LAN                                   IEM Chengdu 2024
# 264 2024-04-13  Intl. LAN                                   IEM Chengdu 2024
# 265 2024-04-13  Intl. LAN                                   IEM Chengdu 2024
# 266 2024-04-14  Intl. LAN                                   IEM Chengdu 2024
#
#      Best Of  Stars             Team A         Team B  Moneyline A  \
# 0          3      1             Aurora          Apeks        1.645
# 1          3      0          Metizport             B8        1.833
# 2          3      0              Monte    GamerLegion        1.741
# 3          3      0  Ninjas in Pyjamas        BlesseD        1.364
# 4          3      3               FaZe  Natus Vincere        1.460
# ..       ...    ...                ...            ...          ...
# 262        3      1             Liquid           FaZe        2.870
# 263        3      3         Virtus.pro             G2        2.250
# 264        3      1           Astralis           FaZe        2.210
# 265        3      3               MOUZ             G2        2.170
# 266        3      4               MOUZ           FaZe        2.170
#
#      Moneyline B  R1 Score (A)  ...  R2 Score (A)  R2 Score (B)  R3 Score (A)  \
# 0          2.200            16  ...            13             7           NaN
# 1          1.909            13  ...            13             8           NaN
# 2          2.050            12  ...            13            11          13.0
# 3          3.000            13  ...            13             9           NaN
# 4          2.600             9  ...            13             2           3.0
# ..           ...           ...  ...           ...           ...           ...
# 262        1.380            13  ...            13            11          10.0
# 263        1.600             6  ...            10            13           NaN
# 264        1.620            10  ...            13             5           7.0
# 265        1.640            13  ...             7            13          13.0
# 266        1.630            10  ...             6            13           NaN
#
#      R3 Score (B)  R4 Score (A)  R4 Score (B)  R5 Score (A)  R5 Score (B)  \
# 0             NaN           NaN           NaN           NaN           NaN
# 1             NaN           NaN           NaN           NaN           NaN
# 2            10.0           NaN           NaN           NaN           NaN
# 3             NaN           NaN           NaN           NaN           NaN
# 4            13.0           NaN           NaN           NaN           NaN
# ..            ...           ...           ...           ...           ...
# 262          13.0           NaN           NaN           NaN           NaN
# 263           NaN           NaN           NaN           NaN           NaN
# 264          13.0           NaN           NaN           NaN           NaN
# 265          10.0           NaN           NaN           NaN           NaN
# 266           NaN           NaN           NaN           NaN           NaN
#
#      Score Count (A)  Score Count (B)
# 0                NaN              NaN
# 1                NaN              NaN
# 2                NaN              NaN
# 3                NaN              NaN
# 4                NaN              NaN
# ..               ...              ...
# 262              NaN              NaN
# 263              NaN              NaN
# 264              NaN              NaN
# 265              NaN              NaN
# 266              NaN              NaN
#
# [267 rows x 21 columns]

# %%
cs2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             267 non-null    datetime64[ns]
#  1   Type             267 non-null    object
#  2   League           267 non-null    object
#  3   Best Of          267 non-null    int64
#  4   Stars            267 non-null    int64
#  5   Team A           267 non-null    object
#  6   Team B           267 non-null    object
#  7   Moneyline A      267 non-null    float64
#  8   Moneyline B      267 non-null    float64
#  9   R1 Score (A)     267 non-null    int64
#  10  R1 Score (B)     267 non-null    int64
#  11  R2 Score (A)     267 non-null    int64
#  12  R2 Score (B)     267 non-null    int64
#  13  R3 Score (A)     117 non-null    float64
#  14  R3 Score (B)     117 non-null    float64
#  15  R4 Score (A)     2 non-null      float64
#  16  R4 Score (B)     2 non-null      float64
#  17  R5 Score (A)     1 non-null      float64
#  18  R5 Score (B)     1 non-null      float64
#  19  Score Count (A)  0 non-null      float64
#  20  Score Count (B)  0 non-null      float64
# dtypes: datetime64[ns](1), float64(10), int64(6), object(4)
# memory usage: 43.9+ KB

# %%
cs2['Score Count (A)'] = (
    np.where((cs2['Best Of'] == 3) & (cs2['R1 Score (A)'] > cs2['R1 Score (B)']), 1, 0) +
    np.where((cs2['Best Of'] == 3) & (cs2['R2 Score (A)'] > cs2['R2 Score (B)']), 1, 0) +
    np.where((cs2['Best Of'] == 3) & (cs2['R3 Score (A)'] != 0) & (cs2['R3 Score (A)'] > cs2['R3 Score (B)']), 1, 0) +
    np.where((cs2['Best Of'] == 5) & (cs2['R1 Score (A)'] > cs2['R1 Score (B)']), 1, 0) +
    np.where((cs2['Best Of'] == 5) & (cs2['R2 Score (A)'] > cs2['R2 Score (B)']), 1, 0) +
    np.where((cs2['Best Of'] == 5) & (cs2['R3 Score (A)'] > cs2['R3 Score (B)']), 1, 0) +
    np.where((cs2['Best Of'] == 5) & (cs2['R4 Score (A)'] > cs2['R4 Score (B)']), 1, 0) +
    np.where((cs2['Best Of'] == 5) & (cs2['R5 Score (A)'] != 0) & (cs2['R5 Score (A)'] > cs2['R5 Score (B)']), 1, 0)
)

# %%
cs2['Score Count (B)'] = (
    np.where((cs2['Best Of'] == 3) & (cs2['R1 Score (B)'] > cs2['R1 Score (A)']), 1, 0) +
    np.where((cs2['Best Of'] == 3) & (cs2['R2 Score (B)'] > cs2['R2 Score (A)']), 1, 0) +
    np.where((cs2['Best Of'] == 3) & (cs2['R3 Score (A)'] != 0) & (cs2['R3 Score (B)'] > cs2['R3 Score (A)']), 1, 0) +
    np.where((cs2['Best Of'] == 5) & (cs2['R1 Score (B)'] > cs2['R1 Score (A)']), 1, 0) +
    np.where((cs2['Best Of'] == 5) & (cs2['R2 Score (B)'] > cs2['R2 Score (A)']), 1, 0) +
    np.where((cs2['Best Of'] == 5) & (cs2['R3 Score (B)'] > cs2['R3 Score (A)']), 1, 0) +
    np.where((cs2['Best Of'] == 5) & (cs2['R4 Score (B)'] > cs2['R4 Score (A)']), 1, 0) +
    np.where((cs2['Best Of'] == 5) & (cs2['R5 Score (A)'] != 0) & (cs2['R5 Score (B)'] > cs2['R5 Score (A)']), 1, 0)
)

# %%
cs2
# Out:
#           Date       Type                                             League  \
# 0   2024-04-15     Online  ESL Challenger Jonkoping 2024 Europe Closed Qu...
# 1   2024-04-15     Online  ESL Challenger Jonkoping 2024 Europe Closed Qu...
# 2   2024-04-15     Online  ESL Challenger Jonkoping 2024 Europe Closed Qu...
# 3   2024-04-15     Online  ESL Challenger Jonkoping 2024 Europe Closed Qu...
# 4   2024-03-31      Major                      PGL CS2 Major Copenhagen 2024
# ..         ...        ...                                                ...
# 262 2024-04-12  Intl. LAN                                   IEM Chengdu 2024
# 263 2024-04-12  Intl. LAN                                   IEM Chengdu 2024
# 264 2024-04-13  Intl. LAN                                   IEM Chengdu 2024
# 265 2024-04-13  Intl. LAN                                   IEM Chengdu 2024
# 266 2024-04-14  Intl. LAN                                   IEM Chengdu 2024
#
#      Best Of  Stars             Team A         Team B  Moneyline A  \
# 0          3      1             Aurora          Apeks        1.645
# 1          3      0          Metizport             B8        1.833
# 2          3      0              Monte    GamerLegion        1.741
# 3          3      0  Ninjas in Pyjamas        BlesseD        1.364
# 4          3      3               FaZe  Natus Vincere        1.460
# ..       ...    ...                ...            ...          ...
# 262        3      1             Liquid           FaZe        2.870
# 263        3      3         Virtus.pro             G2        2.250
# 264        3      1           Astralis           FaZe        2.210
# 265        3      3               MOUZ             G2        2.170
# 266        3      4               MOUZ           FaZe        2.170
#
#      Moneyline B  R1 Score (A)  ...  R2 Score (A)  R2 Score (B)  R3 Score (A)  \
# 0          2.200            16  ...            13             7           NaN
# 1          1.909            13  ...            13             8           NaN
# 2          2.050            12  ...            13            11          13.0
# 3          3.000            13  ...            13             9           NaN
# 4          2.600             9  ...            13             2           3.0
# ..           ...           ...  ...           ...           ...           ...
# 262        1.380            13  ...            13            11          10.0
# 263        1.600             6  ...            10            13           NaN
# 264        1.620            10  ...            13             5           7.0
# 265        1.640            13  ...             7            13          13.0
# 266        1.630            10  ...             6            13           NaN
#
#      R3 Score (B)  R4 Score (A)  R4 Score (B)  R5 Score (A)  R5 Score (B)  \
# 0             NaN           NaN           NaN           NaN           NaN
# 1             NaN           NaN           NaN           NaN           NaN
# 2            10.0           NaN           NaN           NaN           NaN
# 3             NaN           NaN           NaN           NaN           NaN
# 4            13.0           NaN           NaN           NaN           NaN
# ..            ...           ...           ...           ...           ...
# 262          13.0           NaN           NaN           NaN           NaN
# 263           NaN           NaN           NaN           NaN           NaN
# 264          13.0           NaN           NaN           NaN           NaN
# 265          10.0           NaN           NaN           NaN           NaN
# 266           NaN           NaN           NaN           NaN           NaN
#
#      Score Count (A)  Score Count (B)
# 0                  2                0
# 1                  2                0
# 2                  2                1
# 3                  2                0
# 4                  1                2
# ..               ...              ...
# 262                1                2
# 263                0                2
# 264                1                2
# 265                2                1
# 266                0                2
#
# [267 rows x 21 columns]

# %%
cs2['Number of Rounds'] = cs2['Score Count (A)'] + cs2['Score Count (B)']

# %%
# Initialize the Moneyline Result column
cs2['Moneyline Result'] = np.where(cs2['Score Count (A)'] > cs2['Score Count (B)'],
                                   cs2['Moneyline A'],
                                   np.where(cs2['Score Count (B)'] > cs2['Score Count (A)'],
                                            cs2['Moneyline B'],
                                            np.nan))

# %%
conditions = [
    (cs2['Moneyline Result'] == cs2['Moneyline A']) & (cs2['Moneyline A'] < cs2['Moneyline B']),
    (cs2['Moneyline Result'] == cs2['Moneyline B']) & (cs2['Moneyline B'] < cs2['Moneyline A']),
    (cs2['Moneyline Result'] == cs2['Moneyline B']) & (cs2['Moneyline B'] > cs2['Moneyline A']),
    (cs2['Moneyline Result'] == cs2['Moneyline A']) & (cs2['Moneyline A'] > cs2['Moneyline B'])
]

# Results
results = ['Favorite', 'Favorite', 'Underdog', 'Underdog']

# Add Winner column based on Moneyline comparison
cs2['Winner'] = np.select(conditions, results, default=np.nan)

# %%
cs2['Winning Team'] = np.where(
    cs2['Moneyline Result'] == cs2['Moneyline A'],
    cs2['Team A'],
    np.where(
        cs2['Moneyline Result'] == cs2['Moneyline B'],
        cs2['Team B'],
        np.nan
    )
)

# %%
cs2 = cs2[cs2['Best Of'] == 3]

# %%
columns_to_drop = ['R4 Score (A)', 'R4 Score (B)', 'R5 Score (A)', 'R5 Score (B)']

cs2 = cs2.drop(columns=columns_to_drop, axis=1)

# %%
cs2.head()
# Out:
#         Date    Type                                             League  \
# 0 2024-04-15  Online  ESL Challenger Jonkoping 2024 Europe Closed Qu...
# 1 2024-04-15  Online  ESL Challenger Jonkoping 2024 Europe Closed Qu...
# 2 2024-04-15  Online  ESL Challenger Jonkoping 2024 Europe Closed Qu...
# 3 2024-04-15  Online  ESL Challenger Jonkoping 2024 Europe Closed Qu...
# 4 2024-03-31   Major                      PGL CS2 Major Copenhagen 2024
#
#    Best Of  Stars             Team A         Team B  Moneyline A  Moneyline B  \
# 0        3      1             Aurora          Apeks        1.645        2.200
# 1        3      0          Metizport             B8        1.833        1.909
# 2        3      0              Monte    GamerLegion        1.741        2.050
# 3        3      0  Ninjas in Pyjamas        BlesseD        1.364        3.000
# 4        3      3               FaZe  Natus Vincere        1.460        2.600
#
#    R1 Score (A)  ...  R2 Score (A)  R2 Score (B)  R3 Score (A)  R3 Score (B)  \
# 0            16  ...            13             7           NaN           NaN
# 1            13  ...            13             8           NaN           NaN
# 2            12  ...            13            11          13.0          10.0
# 3            13  ...            13             9           NaN           NaN
# 4             9  ...            13             2           3.0          13.0
#
#    Score Count (A)  Score Count (B)  Number of Rounds  Moneyline Result  \
# 0                2                0                 2             1.645
# 1                2                0                 2             1.833
# 2                2                1                 3             1.741
# 3                2                0                 2             1.364
# 4                1                2                 3             2.600
#
#      Winner       Winning Team
# 0  Favorite             Aurora
# 1  Favorite          Metizport
# 2  Favorite              Monte
# 3  Favorite  Ninjas in Pyjamas
# 4  Underdog      Natus Vincere
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Round Winners

# %%
cs2 = calculate_round_winner(cs2, 3)

# %%
cs2['Underdog Comeback'] = np.where(
    (cs2['Round 2 Winner'] == 'Underdog') & (cs2['Round 3 Winner'] == 'Underdog'),
    'Yes',
    'No'
)

# %%
cs2.head()
# Out:
#         Date    Type                                             League  \
# 0 2024-04-15  Online  ESL Challenger Jonkoping 2024 Europe Closed Qu...
# 1 2024-04-15  Online  ESL Challenger Jonkoping 2024 Europe Closed Qu...
# 2 2024-04-15  Online  ESL Challenger Jonkoping 2024 Europe Closed Qu...
# 3 2024-04-15  Online  ESL Challenger Jonkoping 2024 Europe Closed Qu...
# 4 2024-03-31   Major                      PGL CS2 Major Copenhagen 2024
#
#    Best Of  Stars             Team A         Team B  Moneyline A  Moneyline B  \
# 0        3      1             Aurora          Apeks        1.645        2.200
# 1        3      0          Metizport             B8        1.833        1.909
# 2        3      0              Monte    GamerLegion        1.741        2.050
# 3        3      0  Ninjas in Pyjamas        BlesseD        1.364        3.000
# 4        3      3               FaZe  Natus Vincere        1.460        2.600
#
#    R1 Score (A)  ...  Score Count (A)  Score Count (B)  Number of Rounds  \
# 0            16  ...                2                0                 2
# 1            13  ...                2                0                 2
# 2            12  ...                2                1                 3
# 3            13  ...                2                0                 2
# 4             9  ...                1                2                 3
#
#    Moneyline Result    Winner       Winning Team  Round 1 Winner  \
# 0             1.645  Favorite             Aurora        Favorite
# 1             1.833  Favorite          Metizport        Favorite
# 2             1.741  Favorite              Monte        Underdog
# 3             1.364  Favorite  Ninjas in Pyjamas        Favorite
# 4             2.600  Underdog      Natus Vincere        Underdog
#
#    Round 2 Winner  Round 3 Winner Underdog Comeback
# 0        Favorite                                No
# 1        Favorite                                No
# 2        Favorite        Favorite                No
# 3        Favorite                                No
# 4        Favorite        Underdog                No
#
# [5 rows x 25 columns]

# %% [markdown]
# # Analysis

# %%
cs2 = cs2[cs2['Number of Rounds'] == 3]
cs2
# Out:
#           Date       Type                                             League  \
# 2   2024-04-15     Online  ESL Challenger Jonkoping 2024 Europe Closed Qu...
# 4   2024-03-31      Major                      PGL CS2 Major Copenhagen 2024
# 5   2024-03-30      Major                      PGL CS2 Major Copenhagen 2024
# 6   2024-03-30      Major                      PGL CS2 Major Copenhagen 2024
# 9   2024-03-28      Major                      PGL CS2 Major Copenhagen 2024
# ..         ...        ...                                                ...
# 250 2024-04-09  Intl. LAN                                   IEM Chengdu 2024
# 254 2024-04-09  Intl. LAN                                   IEM Chengdu 2024
# 262 2024-04-12  Intl. LAN                                   IEM Chengdu 2024
# 264 2024-04-13  Intl. LAN                                   IEM Chengdu 2024
# 265 2024-04-13  Intl. LAN                                   IEM Chengdu 2024
#
#      Best Of  Stars         Team A         Team B  Moneyline A  Moneyline B  \
# 2          3      0          Monte    GamerLegion        1.741         2.05
# 4          3      3           FaZe  Natus Vincere        1.460         2.60
# 5          3      3  Natus Vincere             G2        2.150         1.64
# 6          3      5       Vitality           FaZe        1.710         2.06
# 9          3      5         Spirit           FaZe        1.360         3.00
# ..       ...    ...            ...            ...          ...          ...
# 250        3      2         HEROIC          FURIA        1.720         2.04
# 254        3      1       FlyQuest     Virtus.pro        5.990         1.11
# 262        3      1         Liquid           FaZe        2.870         1.38
# 264        3      1       Astralis           FaZe        2.210         1.62
# 265        3      3           MOUZ             G2        2.170         1.64
#
#      R1 Score (A)  ...  Score Count (A)  Score Count (B)  Number of Rounds  \
# 2              12  ...                2                1                 3
# 4               9  ...                1                2                 3
# 5              16  ...                2                1                 3
# 6               7  ...                1                2                 3
# 9               7  ...                1                2                 3
# ..            ...  ...              ...              ...               ...
# 250             6  ...                2                1                 3
# 254            14  ...                1                2                 3
# 262            13  ...                1                2                 3
# 264            10  ...                1                2                 3
# 265            13  ...                2                1                 3
#
#      Moneyline Result    Winner   Winning Team  Round 1 Winner  \
# 2               1.741  Favorite          Monte        Underdog
# 4               2.600  Underdog  Natus Vincere        Underdog
# 5               2.150  Underdog  Natus Vincere        Underdog
# 6               2.060  Underdog           FaZe        Underdog
# 9               3.000  Underdog           FaZe        Underdog
# ..                ...       ...            ...             ...
# 250             1.720  Favorite         HEROIC        Underdog
# 254             1.110  Favorite     Virtus.pro        Favorite
# 262             1.380  Favorite           FaZe        Favorite
# 264             1.620  Favorite           FaZe        Favorite
# 265             2.170  Underdog           MOUZ        Underdog
#
#      Round 2 Winner  Round 3 Winner Underdog Comeback
# 2          Favorite        Favorite                No
# 4          Favorite        Underdog                No
# 5          Favorite        Underdog                No
# 6          Favorite        Underdog                No
# 9          Favorite        Underdog                No
# ..              ...             ...               ...
# 250        Favorite        Favorite                No
# 254        Underdog        Favorite                No
# 262        Underdog        Favorite                No
# 264        Underdog        Favorite                No
# 265        Favorite        Underdog                No
#
# [113 rows x 25 columns]

# %%
# Round 3 Underdog Winner
r3_ud = cs2['Round 3 Winner'].eq("Underdog").sum()
r3_ud
# Out:
# 46

# %%
# Round 3 Underdog Winner divided by Total 3 Round Matches
r3_ud_win = r3_ud / cs2['Round 3 Winner'].count()

# %%
r3_ud_win.round(5)
# Out:
# 0.40708

# %%
underdog_comeback = ((cs2['Round 2 Winner'] == "Underdog") & (cs2['Round 3 Winner'] == "Underdog")).sum()
underdog_comeback
# Out:
# 21

# %%
favorite_comeback = ((cs2['Round 2 Winner'] == "Favorite") & (cs2['Round 3 Winner'] == "Favorite")).sum()
favorite_comeback
# Out:
# 30

# %%
ud_cb = underdog_comeback / cs2['Round 3 Winner'].count()
ud_cb
# Out:
# 0.18584070796460178

# %%
fv_cb = favorite_comeback / cs2['Round 3 Winner'].count()
fv_cb
# Out:
# 0.26548672566371684

# %% [markdown]
# # Results

# %%
print("Underdogs win", round(r3_ud_win * 100, 5), "% of the time in round 3.")
print("Fair price =", round(1/r3_ud_win, 5),".")

print()
print("Underdogs comeback at", round(ud_cb * 100, 5), "% of the time.")
print("Fair price =", round(1/ud_cb, 5),".")
# Out:
# Underdogs win 40.70796 % of the time in round 3.
# Fair price = 2.45652 .
#
# Underdogs comeback at 18.58407 % of the time.
# Fair price = 5.38095 .

# %%
print("Favorites win", round((1 - r3_ud_win) * 100, 5), "% of the time in round 3.")
print("Fair price =", round(1/(1 - r3_ud_win), 5),".")

print()
print("Favorites comeback at", round(fv_cb * 100, 5), "% of the time.")
print("Fair price =", round(1/fv_cb, 5),".")
# Out:
# Favorites win 59.29204 % of the time in round 3.
# Fair price = 1.68657 .
#
# Favorites comeback at 26.54867 % of the time.
# Fair price = 3.76667 .
