# %%
import pandas as pd
import numpy as np
from google.colab import drive
import re
import warnings
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns

warnings.filterwarnings("ignore")

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Functions

# %%
def calculate_round_winner(cs2, max_round):
    for round_number in range(1, max_round + 1):
        conditions = []
        choices = ['Favorite', 'Underdog', 'Favorite', 'Underdog']

        # Define conditions based on round number
        if round_number == 1:
            conditions = [
                (cs2['Moneyline A'] < cs2['Moneyline B']) & (cs2['R1 Score (A)'] > cs2['R1 Score (B)']),
                (cs2['Moneyline A'] > cs2['Moneyline B']) & (cs2['R1 Score (A)'] > cs2['R1 Score (B)']),
                (cs2['Moneyline B'] < cs2['Moneyline A']) & (cs2['R1 Score (B)'] > cs2['R1 Score (A)']),
                (cs2['Moneyline B'] > cs2['Moneyline A']) & (cs2['R1 Score (B)'] > cs2['R1 Score (A)'])
            ]
        elif round_number == 2:
            conditions = [
                (cs2['Moneyline A'] < cs2['Moneyline B']) & (cs2['R2 Score (A)'] > cs2['R2 Score (B)']),
                (cs2['Moneyline A'] > cs2['Moneyline B']) & (cs2['R2 Score (A)'] > cs2['R2 Score (B)']),
                (cs2['Moneyline B'] < cs2['Moneyline A']) & (cs2['R2 Score (B)'] > cs2['R2 Score (A)']),
                (cs2['Moneyline B'] > cs2['Moneyline A']) & (cs2['R2 Score (B)'] > cs2['R2 Score (A)'])
            ]
        elif round_number == 3:
            # Check if the 'R3 Score' columns exist
            if 'R3 Score (A)' in cs2.columns and 'R3 Score (B)' in cs2.columns:
                conditions = [
                    (cs2['Moneyline A'] < cs2['Moneyline B']) & (cs2['R3 Score (A)'] > cs2['R3 Score (B)']),
                    (cs2['Moneyline A'] > cs2['Moneyline B']) & (cs2['R3 Score (A)'] > cs2['R3 Score (B)']),
                    (cs2['Moneyline B'] < cs2['Moneyline A']) & (cs2['R3 Score (B)'] > cs2['R3 Score (A)']),
                    (cs2['Moneyline B'] > cs2['Moneyline A']) & (cs2['R3 Score (B)'] > cs2['R3 Score (A)'])
                ]

        # Apply conditions and choices
        if conditions:
            cs2[f'Round {round_number} Winner'] = np.select(conditions, choices, default='')
        else:
            cs2[f'Round {round_number} Winner'] = ''

    return cs2

# %% [markdown]
# # CS Data

# %%
fp = '/content/drive/My Drive/Sports Betting/CS2 - Data.xlsx'

cs2 = pd.read_excel(fp)

# %%
cs2
# Out:
#           Date       Type                  League  Best Of  Stars      Team A  \
# 0   2023-10-16  Intl. LAN         IEM Sydney 2023        3    0.0       Apeks
# 1   2023-10-16  Intl. LAN         IEM Sydney 2023        3    1.0       Monte
# 2   2023-10-16  Intl. LAN         IEM Sydney 2023        3    3.0    Vitality
# 3   2023-10-16  Intl. LAN         IEM Sydney 2023        3    1.0     BetBoom
# 4   2023-10-16  Intl. LAN         IEM Sydney 2023        3    2.0  Complexity
# ..         ...        ...                     ...      ...    ...         ...
# 498 2024-05-21     Online  CCT Global Finals 2024        3    1.0      Aurora
# 499 2024-05-21     Online  CCT Global Finals 2024        3    1.0      Liquid
# 500 2024-05-22     Online  CCT Global Finals 2024        3    NaN         NaN
# 501 2024-05-22     Online  CCT Global Finals 2024        3    NaN         NaN
# 502 2024-05-23     Online  CCT Global Finals 2024        3    NaN         NaN
#
#           Team B Odds Source  Moneyline A  Moneyline B  ...  R3 Score (B)  \
# 0         VERTEX  Oddsportal         1.20         4.01  ...           NaN
# 1      Grayhound  Oddsportal         1.32         3.19  ...           NaN
# 2           FaZe  Oddsportal         1.55         2.40  ...          13.0
# 3    GamerLegion  Oddsportal         1.65         2.18  ...           NaN
# 4             G2  Oddsportal         2.64         1.45  ...           NaN
# ..           ...         ...          ...          ...  ...           ...
# 498     Astralis         NaN          NaN          NaN  ...           NaN
# 499         ENCE         NaN          NaN          NaN  ...           NaN
# 500          NaN         NaN          NaN          NaN  ...           NaN
# 501          NaN         NaN          NaN          NaN  ...           NaN
# 502          NaN         NaN          NaN          NaN  ...           NaN
#
#      R3 Map R4 Score (A)  R4 Score (B)  R4 Map R5 Score (A)  R5 Score (B)  \
# 0       NaN          NaN           NaN     NaN          NaN           NaN
# 1       NaN          NaN           NaN     NaN          NaN           NaN
# 2      Nuke          NaN           NaN     NaN          NaN           NaN
# 3       NaN          NaN           NaN     NaN          NaN           NaN
# 4       NaN          NaN           NaN     NaN          NaN           NaN
# ..      ...          ...           ...     ...          ...           ...
# 498     NaN          NaN           NaN     NaN          NaN           NaN
# 499     NaN          NaN           NaN     NaN          NaN           NaN
# 500     NaN          NaN           NaN     NaN          NaN           NaN
# 501     NaN          NaN           NaN     NaN          NaN           NaN
# 502     NaN          NaN           NaN     NaN          NaN           NaN
#
#      R5 Map Score Count (A)  Score Count (B)
# 0       NaN             NaN              NaN
# 1       NaN             NaN              NaN
# 2       NaN             NaN              NaN
# 3       NaN             NaN              NaN
# 4       NaN             NaN              NaN
# ..      ...             ...              ...
# 498     NaN             NaN              NaN
# 499     NaN             NaN              NaN
# 500     NaN             NaN              NaN
# 501     NaN             NaN              NaN
# 502     NaN             NaN              NaN
#
# [503 rows x 27 columns]

# %%
cs2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 27 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             503 non-null    datetime64[ns]
#  1   Type             503 non-null    object
#  2   League           503 non-null    object
#  3   Best Of          503 non-null    int64
#  4   Stars            500 non-null    float64
#  5   Team A           500 non-null    object
#  6   Team B           500 non-null    object
#  7   Odds Source      479 non-null    object
#  8   Moneyline A      486 non-null    float64
#  9   Moneyline B      486 non-null    float64
#  10  R1 Score (A)     498 non-null    float64
#  11  R1 Score (B)     498 non-null    float64
#  12  R1 Map           495 non-null    object
#  13  R2 Score (A)     498 non-null    float64
#  14  R2 Score (B)     498 non-null    float64
#  15  R2 Map           495 non-null    object
#  16  R3 Score (A)     225 non-null    float64
#  17  R3 Score (B)     225 non-null    float64
#  18  R3 Map           222 non-null    object
#  19  R4 Score (A)     3 non-null      float64
#  20  R4 Score (B)     3 non-null      float64
#  21  R4 Map           3 non-null      object
#  22  R5 Score (A)     1 non-null      float64
#  23  R5 Score (B)     1 non-null      float64
#  24  R5 Map           1 non-null      object
#  25  Score Count (A)  0 non-null      float64
#  26  Score Count (B)  0 non-null      float64
# dtypes: datetime64[ns](1), float64(15), int64(1), object(10)
# memory usage: 106.2+ KB

# %%
cs2['Score Count (A)'] = (
    np.where((cs2['Best Of'] == 3) & (cs2['R1 Score (A)'] > cs2['R1 Score (B)']), 1, 0) +
    np.where((cs2['Best Of'] == 3) & (cs2['R2 Score (A)'] > cs2['R2 Score (B)']), 1, 0) +
    np.where((cs2['Best Of'] == 3) & (cs2['R3 Score (A)'] != 0) & (cs2['R3 Score (A)'] > cs2['R3 Score (B)']), 1, 0) +
    np.where((cs2['Best Of'] == 5) & (cs2['R1 Score (A)'] > cs2['R1 Score (B)']), 1, 0) +
    np.where((cs2['Best Of'] == 5) & (cs2['R2 Score (A)'] > cs2['R2 Score (B)']), 1, 0) +
    np.where((cs2['Best Of'] == 5) & (cs2['R3 Score (A)'] > cs2['R3 Score (B)']), 1, 0) +
    np.where((cs2['Best Of'] == 5) & (cs2['R4 Score (A)'] > cs2['R4 Score (B)']), 1, 0) +
    np.where((cs2['Best Of'] == 5) & (cs2['R5 Score (A)'] != 0) & (cs2['R5 Score (A)'] > cs2['R5 Score (B)']), 1, 0)
)

# %%
cs2['Score Count (B)'] = (
    np.where((cs2['Best Of'] == 3) & (cs2['R1 Score (B)'] > cs2['R1 Score (A)']), 1, 0) +
    np.where((cs2['Best Of'] == 3) & (cs2['R2 Score (B)'] > cs2['R2 Score (A)']), 1, 0) +
    np.where((cs2['Best Of'] == 3) & (cs2['R3 Score (A)'] != 0) & (cs2['R3 Score (B)'] > cs2['R3 Score (A)']), 1, 0) +
    np.where((cs2['Best Of'] == 5) & (cs2['R1 Score (B)'] > cs2['R1 Score (A)']), 1, 0) +
    np.where((cs2['Best Of'] == 5) & (cs2['R2 Score (B)'] > cs2['R2 Score (A)']), 1, 0) +
    np.where((cs2['Best Of'] == 5) & (cs2['R3 Score (B)'] > cs2['R3 Score (A)']), 1, 0) +
    np.where((cs2['Best Of'] == 5) & (cs2['R4 Score (B)'] > cs2['R4 Score (A)']), 1, 0) +
    np.where((cs2['Best Of'] == 5) & (cs2['R5 Score (A)'] != 0) & (cs2['R5 Score (B)'] > cs2['R5 Score (A)']), 1, 0)
)

# %%
cs2
# Out:
#           Date       Type                  League  Best Of  Stars      Team A  \
# 0   2023-10-16  Intl. LAN         IEM Sydney 2023        3    0.0       Apeks
# 1   2023-10-16  Intl. LAN         IEM Sydney 2023        3    1.0       Monte
# 2   2023-10-16  Intl. LAN         IEM Sydney 2023        3    3.0    Vitality
# 3   2023-10-16  Intl. LAN         IEM Sydney 2023        3    1.0     BetBoom
# 4   2023-10-16  Intl. LAN         IEM Sydney 2023        3    2.0  Complexity
# ..         ...        ...                     ...      ...    ...         ...
# 498 2024-05-21     Online  CCT Global Finals 2024        3    1.0      Aurora
# 499 2024-05-21     Online  CCT Global Finals 2024        3    1.0      Liquid
# 500 2024-05-22     Online  CCT Global Finals 2024        3    NaN         NaN
# 501 2024-05-22     Online  CCT Global Finals 2024        3    NaN         NaN
# 502 2024-05-23     Online  CCT Global Finals 2024        3    NaN         NaN
#
#           Team B Odds Source  Moneyline A  Moneyline B  ...  R3 Score (B)  \
# 0         VERTEX  Oddsportal         1.20         4.01  ...           NaN
# 1      Grayhound  Oddsportal         1.32         3.19  ...           NaN
# 2           FaZe  Oddsportal         1.55         2.40  ...          13.0
# 3    GamerLegion  Oddsportal         1.65         2.18  ...           NaN
# 4             G2  Oddsportal         2.64         1.45  ...           NaN
# ..           ...         ...          ...          ...  ...           ...
# 498     Astralis         NaN          NaN          NaN  ...           NaN
# 499         ENCE         NaN          NaN          NaN  ...           NaN
# 500          NaN         NaN          NaN          NaN  ...           NaN
# 501          NaN         NaN          NaN          NaN  ...           NaN
# 502          NaN         NaN          NaN          NaN  ...           NaN
#
#      R3 Map R4 Score (A)  R4 Score (B)  R4 Map R5 Score (A)  R5 Score (B)  \
# 0       NaN          NaN           NaN     NaN          NaN           NaN
# 1       NaN          NaN           NaN     NaN          NaN           NaN
# 2      Nuke          NaN           NaN     NaN          NaN           NaN
# 3       NaN          NaN           NaN     NaN          NaN           NaN
# 4       NaN          NaN           NaN     NaN          NaN           NaN
# ..      ...          ...           ...     ...          ...           ...
# 498     NaN          NaN           NaN     NaN          NaN           NaN
# 499     NaN          NaN           NaN     NaN          NaN           NaN
# 500     NaN          NaN           NaN     NaN          NaN           NaN
# 501     NaN          NaN           NaN     NaN          NaN           NaN
# 502     NaN          NaN           NaN     NaN          NaN           NaN
#
#      R5 Map Score Count (A)  Score Count (B)
# 0       NaN               2                0
# 1       NaN               2                0
# 2       NaN               1                2
# 3       NaN               2                0
# 4       NaN               0                2
# ..      ...             ...              ...
# 498     NaN               0                0
# 499     NaN               0                0
# 500     NaN               0                0
# 501     NaN               0                0
# 502     NaN               0                0
#
# [503 rows x 27 columns]

# %%
cs2['Number of Rounds'] = cs2['Score Count (A)'] + cs2['Score Count (B)']

# %%
# Initialize the Moneyline Result column
cs2['Moneyline Result'] = np.where(cs2['Score Count (A)'] > cs2['Score Count (B)'],
                                   cs2['Moneyline A'],
                                   np.where(cs2['Score Count (B)'] > cs2['Score Count (A)'],
                                            cs2['Moneyline B'],
                                            np.nan))

# %%
conditions = [
    (cs2['Moneyline Result'] == cs2['Moneyline A']) & (cs2['Moneyline A'] < cs2['Moneyline B']),
    (cs2['Moneyline Result'] == cs2['Moneyline B']) & (cs2['Moneyline B'] < cs2['Moneyline A']),
    (cs2['Moneyline Result'] == cs2['Moneyline B']) & (cs2['Moneyline B'] > cs2['Moneyline A']),
    (cs2['Moneyline Result'] == cs2['Moneyline A']) & (cs2['Moneyline A'] > cs2['Moneyline B'])
]

# Results
results = ['Favorite', 'Favorite', 'Underdog', 'Underdog']

# Add Winner column based on Moneyline comparison
cs2['Winner'] = np.select(conditions, results, default=np.nan)

# %%
cs2['Winning Team'] = np.where(
    cs2['Moneyline Result'] == cs2['Moneyline A'],
    cs2['Team A'],
    np.where(
        cs2['Moneyline Result'] == cs2['Moneyline B'],
        cs2['Team B'],
        np.nan
    )
)

# %%
cs2 = cs2[cs2['Best Of'] == 3]

# %%
columns_to_drop = ['R4 Score (A)', 'R4 Score (B)', 'R5 Score (A)', 'R5 Score (B)']

cs2 = cs2.drop(columns=columns_to_drop, axis=1)

# %%
cs2.head()
# Out:
#         Date       Type           League  Best Of  Stars      Team A  \
# 0 2023-10-16  Intl. LAN  IEM Sydney 2023        3    0.0       Apeks
# 1 2023-10-16  Intl. LAN  IEM Sydney 2023        3    1.0       Monte
# 2 2023-10-16  Intl. LAN  IEM Sydney 2023        3    3.0    Vitality
# 3 2023-10-16  Intl. LAN  IEM Sydney 2023        3    1.0     BetBoom
# 4 2023-10-16  Intl. LAN  IEM Sydney 2023        3    2.0  Complexity
#
#         Team B Odds Source  Moneyline A  Moneyline B  ...  R3 Score (B)  \
# 0       VERTEX  Oddsportal         1.20         4.01  ...           NaN
# 1    Grayhound  Oddsportal         1.32         3.19  ...           NaN
# 2         FaZe  Oddsportal         1.55         2.40  ...          13.0
# 3  GamerLegion  Oddsportal         1.65         2.18  ...           NaN
# 4           G2  Oddsportal         2.64         1.45  ...           NaN
#
#    R3 Map R4 Map  R5 Map  Score Count (A) Score Count (B)  Number of Rounds  \
# 0     NaN    NaN     NaN                2               0                 2
# 1     NaN    NaN     NaN                2               0                 2
# 2    Nuke    NaN     NaN                1               2                 3
# 3     NaN    NaN     NaN                2               0                 2
# 4     NaN    NaN     NaN                0               2                 2
#
#    Moneyline Result    Winner Winning Team
# 0              1.20  Favorite        Apeks
# 1              1.32  Favorite        Monte
# 2              2.40  Underdog         FaZe
# 3              1.65  Favorite      BetBoom
# 4              1.45  Favorite           G2
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Round Winners

# %%
cs2 = calculate_round_winner(cs2, 3)
cs2
# Out:
#           Date       Type                  League  Best Of  Stars      Team A  \
# 0   2023-10-16  Intl. LAN         IEM Sydney 2023        3    0.0       Apeks
# 1   2023-10-16  Intl. LAN         IEM Sydney 2023        3    1.0       Monte
# 2   2023-10-16  Intl. LAN         IEM Sydney 2023        3    3.0    Vitality
# 3   2023-10-16  Intl. LAN         IEM Sydney 2023        3    1.0     BetBoom
# 4   2023-10-16  Intl. LAN         IEM Sydney 2023        3    2.0  Complexity
# ..         ...        ...                     ...      ...    ...         ...
# 498 2024-05-21     Online  CCT Global Finals 2024        3    1.0      Aurora
# 499 2024-05-21     Online  CCT Global Finals 2024        3    1.0      Liquid
# 500 2024-05-22     Online  CCT Global Finals 2024        3    NaN         NaN
# 501 2024-05-22     Online  CCT Global Finals 2024        3    NaN         NaN
# 502 2024-05-23     Online  CCT Global Finals 2024        3    NaN         NaN
#
#           Team B Odds Source  Moneyline A  Moneyline B  ...  R5 Map  \
# 0         VERTEX  Oddsportal         1.20         4.01  ...     NaN
# 1      Grayhound  Oddsportal         1.32         3.19  ...     NaN
# 2           FaZe  Oddsportal         1.55         2.40  ...     NaN
# 3    GamerLegion  Oddsportal         1.65         2.18  ...     NaN
# 4             G2  Oddsportal         2.64         1.45  ...     NaN
# ..           ...         ...          ...          ...  ...     ...
# 498     Astralis         NaN          NaN          NaN  ...     NaN
# 499         ENCE         NaN          NaN          NaN  ...     NaN
# 500          NaN         NaN          NaN          NaN  ...     NaN
# 501          NaN         NaN          NaN          NaN  ...     NaN
# 502          NaN         NaN          NaN          NaN  ...     NaN
#
#      Score Count (A) Score Count (B)  Number of Rounds  Moneyline Result  \
# 0                  2               0                 2              1.20
# 1                  2               0                 2              1.32
# 2                  1               2                 3              2.40
# 3                  2               0                 2              1.65
# 4                  0               2                 2              1.45
# ..               ...             ...               ...               ...
# 498                0               0                 0               NaN
# 499                0               0                 0               NaN
# 500                0               0                 0               NaN
# 501                0               0                 0               NaN
# 502                0               0                 0               NaN
#
#        Winner  Winning Team  Round 1 Winner Round 2 Winner Round 3 Winner
# 0    Favorite         Apeks        Favorite       Favorite
# 1    Favorite         Monte        Favorite       Favorite
# 2    Underdog          FaZe        Favorite       Underdog       Underdog
# 3    Favorite       BetBoom        Favorite       Favorite
# 4    Favorite            G2        Favorite       Favorite
# ..        ...           ...             ...            ...            ...
# 498       nan           NaN
# 499       nan           NaN
# 500       nan           NaN
# 501       nan           NaN
# 502       nan           NaN
#
# [496 rows x 30 columns]

# %%
cs2['Underdog Comeback'] = np.where(
    (cs2['Round 2 Winner'] == 'Underdog') & (cs2['Round 3 Winner'] == 'Underdog'),
    'Yes',
    'No'
)

# %%
cs2.head()
# Out:
#         Date       Type           League  Best Of  Stars      Team A  \
# 0 2023-10-16  Intl. LAN  IEM Sydney 2023        3    0.0       Apeks
# 1 2023-10-16  Intl. LAN  IEM Sydney 2023        3    1.0       Monte
# 2 2023-10-16  Intl. LAN  IEM Sydney 2023        3    3.0    Vitality
# 3 2023-10-16  Intl. LAN  IEM Sydney 2023        3    1.0     BetBoom
# 4 2023-10-16  Intl. LAN  IEM Sydney 2023        3    2.0  Complexity
#
#         Team B Odds Source  Moneyline A  Moneyline B  ...  Score Count (A)  \
# 0       VERTEX  Oddsportal         1.20         4.01  ...                2
# 1    Grayhound  Oddsportal         1.32         3.19  ...                2
# 2         FaZe  Oddsportal         1.55         2.40  ...                1
# 3  GamerLegion  Oddsportal         1.65         2.18  ...                2
# 4           G2  Oddsportal         2.64         1.45  ...                0
#
#    Score Count (B) Number of Rounds  Moneyline Result    Winner Winning Team  \
# 0                0                2              1.20  Favorite        Apeks
# 1                0                2              1.32  Favorite        Monte
# 2                2                3              2.40  Underdog         FaZe
# 3                0                2              1.65  Favorite      BetBoom
# 4                2                2              1.45  Favorite           G2
#
#    Round 1 Winner  Round 2 Winner Round 3 Winner Underdog Comeback
# 0        Favorite        Favorite                               No
# 1        Favorite        Favorite                               No
# 2        Favorite        Underdog       Underdog               Yes
# 3        Favorite        Favorite                               No
# 4        Favorite        Favorite                               No
#
# [5 rows x 31 columns]

# %% [markdown]
# # Analysis

# %% [markdown]
# ## Winner overall

# %%
ud_win_overall = cs2['Winner'].eq("Underdog").sum()
ud_win_overall
# Out:
# 163

# %%
# Total matches
total_matches = cs2['Winner'].count()

# %%
ud_win_pct = ud_win_overall / total_matches
ud_win_pct
# Out:
# 0.3286290322580645

# %% [markdown]
# ## Filter for strategy (map 3)

# %%
cs2 = cs2[cs2['Number of Rounds'] == 3]
cs2
# Out:
#           Date       Type                  League  Best Of  Stars  \
# 2   2023-10-16  Intl. LAN         IEM Sydney 2023        3    3.0
# 5   2023-10-16  Intl. LAN         IEM Sydney 2023        3    4.0
# 6   2023-10-17  Intl. LAN         IEM Sydney 2023        3    2.0
# 7   2023-10-17  Intl. LAN         IEM Sydney 2023        3    2.0
# 9   2023-10-17  Intl. LAN         IEM Sydney 2023        3    2.0
# ..         ...        ...                     ...      ...    ...
# 492 2024-05-19     Online  CCT Global Finals 2024        3    1.0
# 493 2024-05-20     Online  CCT Global Finals 2024        3    2.0
# 495 2024-05-20     Online  CCT Global Finals 2024        3    1.0
# 496 2024-05-21     Online  CCT Global Finals 2024        3    0.0
# 497 2024-05-21     Online  CCT Global Finals 2024        3    2.0
#
#             Team A   Team B Odds Source  Moneyline A  Moneyline B  ...  \
# 2         Vitality     FaZe  Oddsportal         1.55         2.40  ...
# 5    Natus Vincere     MOUZ  Oddsportal         4.36         1.21  ...
# 6             ENCE   fnatic  Oddsportal         1.42         2.73  ...
# 7            Monte   fnatic  Oddsportal         1.92         1.82  ...
# 9       Complexity   Cloud9  Oddsportal         2.41         1.53  ...
# ..             ...      ...         ...          ...          ...  ...
# 492           paiN       OG         NaN         1.76         1.98  ...
# 493           MIBR  BetBoom         NaN         1.55         2.38  ...
# 495            BIG     MIBR         NaN         2.01         1.74  ...
# 496    GamerLegion    AMKAL         NaN          NaN          NaN  ...
# 497   Eternal Fire  BetBoom         NaN          NaN          NaN  ...
#
#      Score Count (A)  Score Count (B) Number of Rounds  Moneyline Result  \
# 2                  1                2                3              2.40
# 5                  1                2                3              1.21
# 6                  2                1                3              1.42
# 7                  2                1                3              1.92
# 9                  2                1                3              2.41
# ..               ...              ...              ...               ...
# 492                2                1                3              1.76
# 493                1                2                3              2.38
# 495                1                2                3              1.74
# 496                2                1                3               NaN
# 497                2                1                3               NaN
#
#        Winner Winning Team  Round 1 Winner  Round 2 Winner Round 3 Winner  \
# 2    Underdog         FaZe        Favorite        Underdog       Underdog
# 5    Favorite         MOUZ        Favorite        Underdog       Favorite
# 6    Favorite         ENCE        Underdog        Favorite       Favorite
# 7    Underdog        Monte        Favorite        Underdog       Underdog
# 9    Underdog   Complexity        Underdog        Favorite       Underdog
# ..        ...          ...             ...             ...            ...
# 492  Favorite         paiN        Underdog        Favorite       Favorite
# 493  Underdog      BetBoom        Favorite        Underdog       Underdog
# 495  Favorite         MIBR        Favorite        Underdog       Favorite
# 496       nan          NaN
# 497       nan          NaN
#
#     Underdog Comeback
# 2                 Yes
# 5                  No
# 6                  No
# 7                 Yes
# 9                  No
# ..                ...
# 492                No
# 493               Yes
# 495                No
# 496                No
# 497                No
#
# [217 rows x 31 columns]

# %%
cs2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 217 entries, 2 to 497
# Data columns (total 31 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               217 non-null    datetime64[ns]
#  1   Type               217 non-null    object
#  2   League             217 non-null    object
#  3   Best Of            217 non-null    int64
#  4   Stars              217 non-null    float64
#  5   Team A             217 non-null    object
#  6   Team B             217 non-null    object
#  7   Odds Source        209 non-null    object
#  8   Moneyline A        212 non-null    float64
#  9   Moneyline B        212 non-null    float64
#  10  R1 Score (A)       217 non-null    float64
#  11  R1 Score (B)       217 non-null    float64
#  12  R1 Map             214 non-null    object
#  13  R2 Score (A)       217 non-null    float64
#  14  R2 Score (B)       217 non-null    float64
#  15  R2 Map             214 non-null    object
#  16  R3 Score (A)       217 non-null    float64
#  17  R3 Score (B)       217 non-null    float64
#  18  R3 Map             214 non-null    object
#  19  R4 Map             0 non-null      object
#  20  R5 Map             0 non-null      object
#  21  Score Count (A)    217 non-null    int64
#  22  Score Count (B)    217 non-null    int64
#  23  Number of Rounds   217 non-null    int64
#  24  Moneyline Result   212 non-null    float64
#  25  Winner             217 non-null    object
#  26  Winning Team       212 non-null    object
#  27  Round 1 Winner     217 non-null    object
#  28  Round 2 Winner     217 non-null    object
#  29  Round 3 Winner     217 non-null    object
#  30  Underdog Comeback  217 non-null    object
# dtypes: datetime64[ns](1), float64(10), int64(4), object(16)
# memory usage: 54.2+ KB

# %%
cs2['Round 3 Winner'].count()
# Out:
# 217

# %%
# Round 3 Underdog Winner
r3_ud = cs2['Round 3 Winner'].eq("Underdog").sum()
r3_ud
# Out:
# 90

# %%
# Round 3 Underdog Winner divided by Total 3 Round Matches
r3_ud_win = r3_ud / cs2['Round 3 Winner'].count()

# %%
r3_ud_win.round(5)
# Out:
# 0.41475

# %%
underdog_comeback = ((cs2['Round 2 Winner'] == "Underdog") & (cs2['Round 3 Winner'] == "Underdog")).sum()
underdog_comeback
# Out:
# 40

# %%
favorite_comeback = ((cs2['Round 2 Winner'] == "Favorite") & (cs2['Round 3 Winner'] == "Favorite")).sum()
favorite_comeback
# Out:
# 60

# %%
ud_cb = underdog_comeback / cs2['Round 3 Winner'].count()
ud_cb
# Out:
# 0.18433179723502305

# %%
fv_cb = favorite_comeback / cs2['Round 3 Winner'].count()
fv_cb
# Out:
# 0.2764976958525346

# %% [markdown]
# # Results

# %%
print("Underdogs win", round((ud_win_pct)*100,5), "% of the time overall.")
print("Fair price =", round(1/ud_win_pct, 5),".")
print()
print("Underdogs win", round(r3_ud_win * 100, 5), "% of the time in map 3.")
print("Fair price =", round(1/r3_ud_win, 5),".")
print()
print("Underdogs comeback at", round(ud_cb * 100, 5), "% of the time.")
print("Fair price =", round(1/ud_cb, 5),".")
# Out:
# Underdogs win 32.8629 % of the time overall.
# Fair price = 3.04294 .
#
# Underdogs win 41.47465 % of the time in map 3.
# Fair price = 2.41111 .
#
# Underdogs comeback at 18.43318 % of the time.
# Fair price = 5.425 .

# %%
print("Favorites win", round((1-(ud_win_pct))*100,5), "% of the time overall.")
print("Fair price =", round(1/(1- ud_win_pct), 5),".")
print()
print("Favorites win", round((1 - r3_ud_win) * 100, 5), "% of the time in map 3.")
print("Fair price =", round(1/(1 - r3_ud_win), 5),".")
print()
print("Favorites comeback at", round(fv_cb * 100, 5), "% of the time.")
print("Fair price =", round(1/fv_cb, 5),".")
# Out:
# Favorites win 67.1371 % of the time overall.
# Fair price = 1.48949 .
#
# Favorites win 58.52535 % of the time in map 3.
# Fair price = 1.70866 .
#
# Favorites comeback at 27.64977 % of the time.
# Fair price = 3.61667 .
